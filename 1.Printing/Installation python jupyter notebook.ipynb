# %% [markdown]
# # 1. Download Python Executable Installer

# %% [markdown]
# ![5.PNG](attachment:5.PNG)

# %% [markdown]
# # 2. Run Executable Installer (Make sure to check the option “Add Python to PATH” during the installation. )

# %% [markdown]
# ![aa.PNG](attachment:aa.PNG)

# %% [markdown]
# * Admin privileges. The parameter controls whether to install Python for the current or all system users. This option allows you to change the installation folder for Python.
# * Add Python to PATH. The second option places the executable in the PATH variable after installation. You can also add Python to the PATH environment variable manually later.
#
# Select the Install Now option for the recommended installation

# %% [markdown]
# # 3. Open CMD and run the command

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# # 4. you can install jupyter notebook using 2 method : pip or conda

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# # 5. To run jupyter notebook

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %% [markdown]
# # 6. If you install jupyter notebook using pip, it has less feature. so use conda method to install jupyter notebook.. so first uninstall it and then we will install using conda

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %% [markdown]
# # 7. Download Anaconda

# %% [markdown]
# ![0.PNG](attachment:0.PNG)

# %% [markdown]
# # 8. Run the Anaconda Installer

# %% [markdown]
# # 9. Launch Jupyter Notebook

# %% [markdown]
# ![00.PNG](attachment:00.PNG)
